# %% [markdown]
# # Scrape Twitter Data for Semantic Analysis
#
# In this code, I'm going to scrape any single user's tweets (including retweets) to the Nth scroll refresh.
# In this particular tutorial, let's scrape CNN.
#
# #### Require Modules:
# Scraping twitter can be done in a number of ways.  The quick method I've employed here, just uses beautiful soup to scrape particular parts of the html as it would any webpage.  The complication with this method is that Twitter restricts the base output from such a function to 20 tweets (and even manually scrolling through more and then running the function doesn't seem to add more data nor is it desirable).  So we have to download and install a package called selenium, which will automatically pull up more tweets.  I've read that if you ping twitter too many times that you can get blocked/cause problems for yourself, so I have a 2s pause for each page scroll.  Not sure how important that is or not.
#
# So the required packages to run this code are: selenium, bs4, time, pymongo, numpy, and pandas.
#
# There are other ways to do this (even ones that use the beautifulsoup method), like finding the html page for a time period of tweets that you want and just scraping that.
#
# ##### Input Variables:
# 1) Twitter-handle (to be added to base url)
# 2) Number of page scrolls.  Right now, this is hard coded, but can easily be adjusted to be a % of total tweets, etc...

# %%
#### Load Modules
from selenium import webdriver
from bs4 import BeautifulSoup
import time
import pymongo
import numpy as np
import pandas as pd

# %%
username='CNN'
url = "https://twitter.com/" + username

# %%
#This next step opens up a chrome window and sets it up for automatic scrolling
# Open webdriver and url
driver = webdriver.Chrome()
#driver = webdriver.firefox()
driver.get(url)
driver.maximize_window()

# %%
# Continuously scroll the window, pausing 2s after each scroll

# lastHeight = driver.execute_script("return document.body.scrollHeight")
# lastHeight = lastHeight/5
lastHeight=100
while True:
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
    time.sleep(2)
    newHeight = driver.execute_script("return document.body.scrollHeight")
    if newHeight == lastHeight:
        break
    lastHeight = newHeight

# %%
#Now that we have a full scroll, use beautiful soup to extract the page contents.  
#This will collect a tooonnnn of extraneous info, so the next step is to grab only what we want.
#The positive flip side is that there is a ton of meta-data to extract if you want.
pho = BeautifulSoup(driver.page_source, "html.parser")

# %%
#For our purposes, we are going to extract the info of the tweet origin (user we are currently looking at or retweet),
# the text of the tweet, the tweet unique ID, and the tweet timestamp.
#All info is saved in tweetFrame

tweets = pho.find_all('li',"js-stream-item")
tweetFrame = pd.DataFrame(columns=["tweet_user","tweet_text","tweet_id","timestamp"])
tweetslist = []
for tweet in tweets:
    if tweet.find('p','tweet-text'):
        tweet_user = tweet.find('span','username').text
        tweet_text = tweet.find('p','tweet-text').text.encode('utf8')
        tweet_id = tweet['data-item-id']
        timestamp = tweet.find('a','tweet-timestamp')['title']
        tweetslist.append([tweet_user,tweet_text,tweet_id,timestamp])
    else:
        continue
tweetFrame = pd.DataFrame(tweetslist,columns=["tweet_user","tweet_text","tweet_id","timestamp"])

# %%
#Let's take a look!
tweetFrame
# Out:
#        tweet_user                                         tweet_text  \
# 0            @CNN  Some people have taken genetic tests to see ho...
# 1            @CNN  New bill seeks to curb tech's sexual harassmen...
# 2            @CNN  One month: @BrookeBCNN lists President Trump's...
# 3            @CNN  We’re in Times Square on World Humanitarian Da...
# 4            @CNN  Who has left the Trump administration? Here's ...
# 5            @CNN  President Trump has had a chaotic past four we...
# 6            @CNN  Donald Trump fired Steve Bannon. But Bannon st...
# 7            @CNN  This fall, Colorado will deploy a fully autono...
# 8            @CNN  Remaining 16 members of the President's Commit...
# 9            @CNN  '#WAR': Breitbart set to take on Trump White H...
# 10   @CNNPolitics  .@BrookeBCNN reminds us what’s happened in the...
# 11           @CNN  This is Donald Trump's worst week as president...
# 12           @CNN  Trump has privately stewed over Bannon in rece...
# 13   @CNNPolitics  Bannon represents the latest high-profile exit...
# 14           @CNN  What if lawmakers or Trump fail on the debt ce...
# 15           @CNN  JUST IN: White House officials say Chief Strat...
# 16           @CNN  Mike Pence compared Donald Trump to Teddy Roos...
# 17           @CNN  'Conscience of a Conservative,' the remix: Wha...
# 18           @CNN  .@Acosta: Steve Bannon essentially “pushed out...
# 19           @CNN  Why do you hate me? A brown woman talks to a f...
# 20           @CNN  BREAKING: Embattled White House Chief Strategi...
# 21           @CNN  Death toll in Sierra Leone mudslides rises to ...
# 22           @CNN  Trump elevates military command that handles c...
# 23           @CNN  Travis Kalanick lashes back at major Uber inve...
# 24           @CNN  Air ball! Nobody's buying expensive sneakersht...
# 25           @CNN  Mitt Romney calls on Trump to apologize over #...
# 26           @CNN  Secretary of State Rex Tillerson on US race re...
# 27           @CNN  How Seattle morphed from bikeshare failure to ...
# 28           @CNN  Georgia NAACP wants all Confederate symbols re...
# 29        @Acosta  WH response via SHS to Heyer's mother: "Our th...
# ..            ...                                                ...
# 776          @CNN  Amazon says it has issued refunds to some cust...
# 777          @CNN  5 things for Monday:\n\n- Charlottesville atta...
# 778          @CNN  People left flowers and cards Sunday in memory...
# 779          @CNN  Teacher says suspect in Virginia car attack "w...
# 780          @CNN  DOJ official: Suspect in Saturday's deadly veh...
# 781          @CNN  Two senior Trump advisers signal the knives ar...
# 782          @CNN  Former WH communications director Anthony Scar...
# 783          @CNN  Charlottesville restaurateur threatened after ...
# 784          @CNN  Colombian President tells VP Mike Pence that U...
# 785          @CNN  The Southern Poverty Law Center has published ...
# 786          @CNN  Jury to hear closing arguments in lawsuit and ...
# 787          @CNN  Number of children going to emergency rooms be...
# 788          @CNN  2 days after Trump failed to rule out interven...
# 789          @CNN  Suspect in Saturday's deadly crash near schedu...
# 790          @CNN  At least 18 people killed after a number of as...
# 791          @CNN  Pakistan marks 70 years of independence with f...
# 792          @CNN  Bill Maher thought Trump would crash the stock...
# 793          @CNN  As US military official arrives in S. Korea, t...
# 794          @CNN  17 undocumented immigrants discovered Sunday l...
# 795          @CNN  17 people were killed after a number of assail...
# 796          @CNN  Why Donald Trump's words -- and omissions -- m...
# 797          @CNN  Amazon says it has issued refunds to some cust...
# 798          @CNN  Landslide in India sweeps away two buses; near...
# 799          @CNN  Former WH communications director Anthony Scar...
# 800          @CNN  A "very drunk" American man was punched for ma...
# 801          @CNN  US VP Mike Pence denounces 'hate and violence ...
# 802          @CNN  2 days after Trump failed to rule out interven...
# 803          @CNN  As North Korea threat over Guam looms, the isl...
# 804          @CNN  How is the 70th anniversary of independence be...
# 805          @CNN  US' top military official arrives in South Kor...
#
#                tweet_id               timestamp
# 0    898649381452304386   1:54 PM - 18 Aug 2017
# 1    898646989570588672   1:45 PM - 18 Aug 2017
# 2    898645513817305088   1:39 PM - 18 Aug 2017
# 3    898644995183263744   1:37 PM - 18 Aug 2017
# 4    898644317505564674   1:34 PM - 18 Aug 2017
# 5    898639722037235713   1:16 PM - 18 Aug 2017
# 6    898637528298774528   1:07 PM - 18 Aug 2017
